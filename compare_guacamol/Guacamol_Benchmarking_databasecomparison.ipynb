# %%
from typing import List
import argparse
import os
import numpy as np
from pickle import load


from guacamol.distribution_matching_generator import DistributionMatchingGenerator
from guacamol.assess_distribution_learning import assess_distribution_learning
from guacamol.utils.helpers import setup_default_logger

import pandas as pd

class RandomSmilesSampler(DistributionMatchingGenerator):
    """
    Generator that samples SMILES strings from a predefined list.
    Shuffles the list and returns the first N samples to avoid duplicates and bias.
    """

    def __init__(self, molecules: List[str]) -> None:
        """
        Args:
            molecules: list of molecules from which the samples will be drawn
        """
        self.molecules = list(np.random.permutation(molecules))
        self.molecules = molecules

    def generate(self, number_samples: int) -> List[str]:
       
        return self.molecules[:number_samples]

setup_default_logger()

description='Molecule distribution learning benchmark for random smiles sampler'
dist_file='../Data/guacamol_v1_train.smiles'
output_dir = None
suite='v2'

if output_dir is None:
    output_dir = os.getcwd()

    
with open('../Data/guacamol_v1_train_lt70.smiles', 'r') as f:
    smiles_list = [line.strip() for line in f]

generator = RandomSmilesSampler(molecules=smiles_list)


json_file_path = os.path.join(output_dir, '../Data/distribution_learning_results.json')


#hacer un print del smiles tambien

assess_distribution_learning(generator,
                             chembl_training_file=dist_file,
                             json_output_file=json_file_path,
                             benchmark_version=suite)
# Out:
# INFO : Benchmarking distribution learning, version v2
# INFO : Number of benchmarks: 5
# INFO : Running benchmark 1/5: Validity
# INFO : Results for the benchmark "Validity":
# INFO :   Score: 1.000000
# INFO :   Sampling time: 0:00:00
# INFO :   Metadata: {'number_samples': 10000, 'number_valid': 10000}
# INFO : Running benchmark 2/5: Uniqueness
# INFO : Results for the benchmark "Uniqueness":
# INFO :   Score: 1.000000
# INFO :   Sampling time: 0:00:00
# INFO :   Metadata: {'number_samples': 10000, 'number_unique': 10000}
# INFO : Running benchmark 3/5: Novelty
# INFO : Results for the benchmark "Novelty":
# INFO :   Score: 0.000000
# INFO :   Sampling time: 0:00:01
# INFO :   Metadata: {'number_samples': 10000, 'number_novel': 0}
# INFO : Running benchmark 4/5: KL divergence
# INFO : Results for the benchmark "KL divergence":
# INFO :   Score: 0.966882
# INFO :   Sampling time: 0:00:01
# INFO :   Metadata: {'number_samples': 10000, 'kl_divs': {'BertzCT': 0.02439807383279423, 'MolLogP': 0.04367630764836341, 'MolWt': 0.098607609211801, 'TPSA': 0.017401020123402007, 'NumHAcceptors': 0.013494416021706594, 'NumHDonors': 0.021481362129467, 'NumRotatableBonds': 0.09660047756987576, 'NumAliphaticRings': 0.019170031252839434, 'NumAromaticRings': 0.004080457291528425, 'internal_similarity': 0.003402053766852481}}
# INFO : Running benchmark 5/5: Frechet ChemNet Distance
# INFO : Saved ChemNet model to '/tmp/ChemNet_v0.13_pretrained.pt'
# INFO : Results for the benchmark "Frechet ChemNet Distance":
# INFO :   Score: 0.895303
# INFO :   Sampling time: 0:00:00
# INFO :   Metadata: {'number_reference_molecules': 10000, 'number_generated_molecules': 10000, 'FCD': 0.5529647030753182}
# INFO : Finished execution of the benchmarks
# INFO : Save results to file /export/home/shared/Projects/Manu22-23/MoleculeDifusion/CoCoGraph/compare_guacamol/../Data/distribution_learning_results.json

# %%
from typing import List
import argparse
import os
import numpy as np
from pickle import load


from guacamol.distribution_matching_generator import DistributionMatchingGenerator
from guacamol.assess_distribution_learning import assess_distribution_learning
from guacamol.utils.helpers import setup_default_logger

import pandas as pd

class RandomSmilesSampler(DistributionMatchingGenerator):
    """
    Generator that samples SMILES strings from a predefined list.
    Shuffles the list and returns the first N samples to avoid duplicates and bias.
    """

    def __init__(self, molecules: List[str]) -> None:
        """
        Args:
            molecules: list of molecules from which the samples will be drawn
        """
        self.molecules = list(np.random.permutation(molecules))
        self.molecules = molecules

    def generate(self, number_samples: int) -> List[str]:
       
        return self.molecules[:number_samples]

setup_default_logger()

description='Molecule distribution learning benchmark for random smiles sampler'
dist_file='../Data/guacamol_v1_train.smiles'
output_dir = None
suite='v2'

if output_dir is None:
    output_dir = os.getcwd()

    
with open('../Data/training_smiles.smiles', 'r') as f:
    smiles_list = [line.strip() for line in f]

generator = RandomSmilesSampler(molecules=smiles_list)


json_file_path = os.path.join(output_dir, '../Data/distribution_learning_results.json')


#hacer un print del smiles tambien

assess_distribution_learning(generator,
                             chembl_training_file=dist_file,
                             json_output_file=json_file_path,
                             benchmark_version=suite)
# Out:
# INFO : Benchmarking distribution learning, version v2
# INFO : Number of benchmarks: 5
# INFO : Running benchmark 1/5: Validity
# INFO : Results for the benchmark "Validity":
# INFO :   Score: 1.000000
# INFO :   Sampling time: 0:00:00
# INFO :   Metadata: {'number_samples': 10000, 'number_valid': 10000}
# INFO : Running benchmark 2/5: Uniqueness
# INFO : Results for the benchmark "Uniqueness":
# INFO :   Score: 0.999400
# INFO :   Sampling time: 0:00:00
# INFO :   Metadata: {'number_samples': 10000, 'number_unique': 9994}
# INFO : Running benchmark 3/5: Novelty
# INFO : Results for the benchmark "Novelty":
# INFO :   Score: 0.425000
# INFO :   Sampling time: 0:00:01
# INFO :   Metadata: {'number_samples': 10000, 'number_novel': 4250}
# INFO : Running benchmark 4/5: KL divergence
# INFO : Results for the benchmark "KL divergence":
# INFO :   Score: 0.971911
# INFO :   Sampling time: 0:00:01
# INFO :   Metadata: {'number_samples': 10000, 'kl_divs': {'BertzCT': 0.057357346685253704, 'MolLogP': 0.026664735757427276, 'MolWt': 0.09034831797702098, 'TPSA': 0.0117544220835788, 'NumHAcceptors': 0.01600690075222335, 'NumHDonors': 0.00544973904968574, 'NumRotatableBonds': 0.04195478965203496, 'NumAliphaticRings': 0.013260009022375067, 'NumAromaticRings': 0.0213529701245265, 'internal_similarity': 0.0040702497751968734}}
# INFO : Running benchmark 5/5: Frechet ChemNet Distance
# INFO : Saved ChemNet model to '/tmp/ChemNet_v0.13_pretrained.pt'
# INFO : Results for the benchmark "Frechet ChemNet Distance":
# INFO :   Score: 0.858177
# INFO :   Sampling time: 0:00:00
# INFO :   Metadata: {'number_reference_molecules': 10000, 'number_generated_molecules': 10000, 'FCD': 0.764725273939689}
# INFO : Finished execution of the benchmarks
# INFO : Save results to file /export/home/shared/Projects/Manu22-23/MoleculeDifusion/CoCoGraph/compare_guacamol/../Data/distribution_learning_results.json

# %%
from typing import List
import argparse
import os
import numpy as np
from pickle import load


from guacamol.distribution_matching_generator import DistributionMatchingGenerator
from guacamol.assess_distribution_learning import assess_distribution_learning
from guacamol.utils.helpers import setup_default_logger

import pandas as pd

class RandomSmilesSampler(DistributionMatchingGenerator):
    """
    Generator that samples SMILES strings from a predefined list.
    Shuffles the list and returns the first N samples to avoid duplicates and bias.
    """

    def __init__(self, molecules: List[str]) -> None:
        """
        Args:
            molecules: list of molecules from which the samples will be drawn
        """
        self.molecules = list(np.random.permutation(molecules))
        self.molecules = molecules

    def generate(self, number_samples: int) -> List[str]:
       
        return self.molecules[:number_samples]

setup_default_logger()

description='Molecule distribution learning benchmark for random smiles sampler'
dist_file='../Data/guacamol_v1_train_lt70.smiles'
output_dir = None
suite='v2'

if output_dir is None:
    output_dir = os.getcwd()

    
with open('../Data/training_smiles.smiles', 'r') as f:
    smiles_list = [line.strip() for line in f]

generator = RandomSmilesSampler(molecules=smiles_list)


json_file_path = os.path.join(output_dir, '../Data/distribution_learning_results.json')


#hacer un print del smiles tambien

assess_distribution_learning(generator,
                             chembl_training_file=dist_file,
                             json_output_file=json_file_path,
                             benchmark_version=suite)
# Out:
# INFO : Benchmarking distribution learning, version v2
# INFO : Number of benchmarks: 5
# INFO : Running benchmark 1/5: Validity
# INFO : Results for the benchmark "Validity":
# INFO :   Score: 1.000000
# INFO :   Sampling time: 0:00:00
# INFO :   Metadata: {'number_samples': 10000, 'number_valid': 10000}
# INFO : Running benchmark 2/5: Uniqueness
# INFO : Results for the benchmark "Uniqueness":
# INFO :   Score: 0.999400
# INFO :   Sampling time: 0:00:00
# INFO :   Metadata: {'number_samples': 10000, 'number_unique': 9994}
# INFO : Running benchmark 3/5: Novelty
# INFO : Results for the benchmark "Novelty":
# INFO :   Score: 0.437800
# INFO :   Sampling time: 0:00:01
# INFO :   Metadata: {'number_samples': 10000, 'number_novel': 4378}
# INFO : Running benchmark 4/5: KL divergence
# INFO : Results for the benchmark "KL divergence":
# INFO :   Score: 0.987199
# INFO :   Sampling time: 0:00:01
# INFO :   Metadata: {'number_samples': 10000, 'kl_divs': {'BertzCT': 0.02893529730985396, 'MolLogP': 0.013404170714932735, 'MolWt': 0.020163472803134116, 'TPSA': 0.010623807992140667, 'NumHAcceptors': 0.009321600475004601, 'NumHDonors': 0.005342792310502134, 'NumRotatableBonds': 0.0074215447115443, 'NumAliphaticRings': 0.0019968475070136766, 'NumAromaticRings': 0.02786567761716122, 'internal_similarity': 0.004180914448584483}}
# INFO : Running benchmark 5/5: Frechet ChemNet Distance
# INFO : Saved ChemNet model to '/tmp/ChemNet_v0.13_pretrained.pt'
# INFO : Results for the benchmark "Frechet ChemNet Distance":
# INFO :   Score: 0.867397
# INFO :   Sampling time: 0:00:00
# INFO :   Metadata: {'number_reference_molecules': 10000, 'number_generated_molecules': 10000, 'FCD': 0.7112903394653216}
# INFO : Finished execution of the benchmarks
# INFO : Save results to file /export/home/shared/Projects/Manu22-23/MoleculeDifusion/CoCoGraph/compare_guacamol/../Data/distribution_learning_results.json
